# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import brands
from latex_conf import build_latex_confusion_matrix

import util

# %% [markdown]
# ## Changes
# + Test first 8 instead of 2 predicted rois
# + siamese threshold is now 0.83 -> 0.9

# %%
base_path_phish = "../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2"
base_path_benign = "../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign"

# %%
df_phish = pd.read_csv("result_v2_long2_opti.txt", sep="\t")
df_phish["is_phish"] = 1
df_benign = pd.read_csv("result_v2_benign_opti.txt", sep="\t")
df_benign["is_phish"] = 0

#df_phish = df_phish[df_phish['true_brand'].isin(brands.brands)]

df = df_phish.append(df_benign, ignore_index=True)

df_phish_old = df_phish
df_phish["phish_category"] = np.where(df_phish['true_brand'] == df_phish['pred_brand'], 1, 0)
df_rec = df_phish.append(df_benign, ignore_index=True)
# Out:
# /tmp/ipykernel_135764/688080490.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_phish.append(df_benign, ignore_index=True)
# /tmp/ipykernel_135764/688080490.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rec = df_phish.append(df_benign, ignore_index=True)

# %%
print(f"Phishing sites: {df_phish.shape}")
print(f"Legit sites: {df_benign.shape}")
print(f"Dataframe sites: {df.shape}")
# Out:
# Phishing sites: (17456, 7)
# Legit sites: (13465, 7)
# Dataframe sites: (30921, 7)

# %%
confusion_matrix = pd.crosstab(df['is_phish'], df['phish_category'], rownames=['Actual'], colnames=['Predicted'], margins=True)
confusion_matrix_rec = pd.crosstab(df_rec['is_phish'], df_rec['phish_category'], rownames=['Actual'], colnames=['Predicted'], margins=True)

# %%
confusion_matrix
# Out:
# Predicted      0     1    All
# Actual
# 0          12960   505  13465
# 1          14703  2753  17456
# All        27663  3258  30921

# %%
confusion_matrix_rec
# Out:
# Predicted      0     1    All
# Actual
# 0          12960   505  13465
# 1          15282  2174  17456
# All        28242  2679  30921

# %%
util.precision_sensitivity(confusion_matrix, confusion_matrix_rec)
# Out:
# Precision: 0.8449969306322898, Precision brand: 0.8114968271743188
# Sensitivity: 0.1577108157653529, Sensitivity brand: 0.12454170485792851

# %% [markdown]
# # Error Details

# %% [markdown]
# ## False Negatives

# %%
fn = df[(df['phish_category'] == 0) & (df['is_phish'] == 1)]
print(fn.shape)
# Out:
# (14703, 7)

# %%
util.print_some_errors(fn, base_path_phish)
# Out:
# ['../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/DHL Airways+185/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/AT&T+232/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Facebook+10/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Netflix+452/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Standard Chartered Bank+191/shot.png']

# %% [markdown]
# ## False Positives

# %%
fp = df[(df['phish_category'] == 1) & (df['is_phish'] == 0)]
print(fp.shape)
# Out:
# (505, 7)

# %%
util.print_some_errors(fp, base_path_benign)
# Out:
# ['../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign/www.jewelryandcoinbanc.com/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign/customer-service.on-running.com/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign/www.lawsons.co.uk/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign/dmsappcf.dealercenter.net/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_benign/www.free-calendar-template.com/shot.png']

# %% [markdown]
# ## True Positive - False Brand detection

# %%
brand_err = df_phish_old[(df_phish_old['true_brand'] != df_phish_old['pred_brand']) & df_phish_old['pred_brand']]
print(brand_err.shape)
# Out:
# (579, 7)

# %%
util.print_some_errors(brand_err, base_path_phish)
# Out:
# ['../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/1&1 Ionos+288/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Facebook+140/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/1&1 Ionos+387/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Banca Sella+449/shot.png',
#  '../../PHISHPEDIA/Phishpedia/phishpedia/datasets/own_dataset_phish_long2/Credit Agricole+164/shot.png']

# %%
examples_fn = [
    "own_dataset_phish_long2/American Express+215/shot.png",
    "own_dataset_phish_long2/GoDaddy+142/shot.png",
    "own_dataset_phish_long2/Societe Generale+130/shot.png",
    "own_dataset_phish_long2/DocuSign+453/shot.png",
    "own_dataset_phish_long2/Deutsche Telekom+387/shot.png",
    "own_dataset_phish_long2/Standard Chartered Bank+293/shot.png",
    "own_dataset_phish_long2/Blockchain+353/shot.png",
    "own_dataset_phish_long2/American Express+120/shot.png"
]

examples_fp = [
    "own_dataset_benign/rr1---sn-i5heen7r.gvt1.com/shot.png",
    "own_dataset_benign/uncg.edu/shot.png",
    "own_dataset_benign/cognito-identity.ca-central-1.amazonaws.com/shot.png",
    "own_dataset_benign/rr1---sn-pmcg-bg0s.googlevideo.com/shot.png",
    "own_dataset_benign/delta206.rtb.appier.net/shot.png",
    "own_dataset_benign/ideal.bunq.com/shot.png",
    "own_dataset_benign/fm.tuba.pl/shot.png",
    "own_dataset_benign/www.metrotransit.org/shot.png"
]

examples_false_brand = [
    "own_dataset_phish_long2/Interac+56/shot.png",
    "own_dataset_phish_long2/PostFinance+312/shot.png",
    "own_dataset_phish_long2/WeTransfer+383/shot.png",
    "own_dataset_phish_long2/Standard Chartered Bank+180/shot.png",
    "own_dataset_phish_long2/PostFinance+395/shot.png",
    "own_dataset_phish_long2/Leboncoin+372/shot.png",
    "own_dataset_phish_long2/Blockchain+122/shot.png",
    "own_dataset_phish_long2/Google+25/shot.png"
]

# %% [markdown]
# # Statistic for Latex

# %%
print(build_latex_confusion_matrix(confusion_matrix))
# Out:
# \def \cTP {2753}
# \def \cFP {505}
# \def \cTN {12960}
# \def \cFN {14703}
# \def \ctiP {17456}
# \def \ctiN {13465}
# \def \ctpP {3258}
# \def \cFpN {27663}
# \def \ctotal {30921}
# \def \cPPV {84.5\%}
# \def \cTPR {15.8\%}
# \def \cACC {50.8\%}

# %%
print(build_latex_confusion_matrix(confusion_matrix_rec))
# Out:
# \def \cTP {2174}
# \def \cFP {505}
# \def \cTN {12960}
# \def \cFN {15282}
# \def \ctiP {17456}
# \def \ctiN {13465}
# \def \ctpP {2679}
# \def \cFpN {28242}
# \def \ctotal {30921}
# \def \cPPV {81.1\%}
# \def \cTPR {12.5\%}
# \def \cACC {48.9\%}
